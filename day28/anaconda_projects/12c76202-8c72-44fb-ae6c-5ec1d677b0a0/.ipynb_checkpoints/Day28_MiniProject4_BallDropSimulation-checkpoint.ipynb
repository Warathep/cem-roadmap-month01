# %% [markdown]
# ## 📚 หลักการฟิสิกส์ที่ใช้
#
# - สมมติว่าไม่มีแรงต้านอากาศ
# - ความเร่งจากแรงโน้มถ่วง: $g = 9.81 \space \text{m/s}^2$
# - ความสูง:
#
#     $$
#     h(t) = h_0 - \frac{1}{2}gt^2
#     $$
#
# - ความเร็ว:
#
#     $$
#     v(t) = -gt
#     $$

# %% [markdown]
# 🖥️ ตัวอย่างโค้ดจำลองการตกของลูกบอล

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# พารามิเตอร์
h0 = 20       # ความสูงเริ่มต้น (เมตร)
g = 9.81      # ความเร่งโน้มถ่วง (m/s^2)
t_end = np.sqrt(2 * h0 / g)  # เวลาที่ลูกบอลถึงพื้น
t = np.linspace(0, t_end, 100)

# %%
# คำนวณตำแหน่งและความเร็ว
height = h0 - 0.5 * g * t**2
velocity = -g * t

# %%
# Plot ความสูง
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(t, height, label='Height (m)', color='blue')
plt.xlabel("Time (s)")
plt.ylabel("Height (m)")
plt.title("Ball Drop: Height vs Time")
plt.grid(True)
plt.legend()

# %%
# Plot ความเร็ว
plt.subplot(1, 2, 2)
plt.plot(t, velocity, label='Velocity (m/s)', color='red')
plt.xlabel("Time (s)")
plt.ylabel("Velocity (m/s)")
plt.title("Ball Drop: Velocity vs Time")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
