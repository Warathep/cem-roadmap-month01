# %% [markdown]
# ## 📚 เนื้อหาที่เรียนวันนี้
#
# ### 1. สมการที่ใช้ทดสอบ
#
# $$
# \frac{dy}{dt} = -2y, \quad y(0) = 5
# $$
#
# คำตอบจริง:
#
# $$
# y(t) = 5e^{-2t}
# $$

# %% [markdown]
# 2. โค้ดเปรียบเทียบ step size

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(t, y):
    return -2 * y

# %%
def euler_method(f, y0, t0, t_end, h):
    t_values = np.arange(t0, t_end + h, h)
    y_values = np.zeros(len(t_values))
    y_values[0] = y0
    for i in range(len(t_values) - 1):
        y_values[i+1] = y_values[i] + h * f(t_values[i], y_values[i])
    return t_values, y_values

# %%
# เงื่อนไขเริ่มต้น
y0 = 5
t0 = 0
t_end = 5

# %%
# คำตอบจริง
t_exact = np.linspace(t0, t_end, 1000)
y_exact = y0 * np.exp(-2 * t_exact)

# %%
# เปรียบเทียบ step size
step_sizes = [0.5, 0.2, 0.05]

# %%
plt.plot(t_exact, y_exact, 'k-', label='Exact Solution')

plt.title("Effect of Step Size on Accuracy")
plt.xlabel("Time t")
plt.ylabel("y(t)")
plt.legend()
plt.grid(True)
plt.show()

# %%
for h in step_sizes:
    t_num, y_num = euler_method(f, y0, t0, t_end, h)
    plt.plot(t_num, y_num, marker='o', label=f'Euler h={h}')

plt.title("Effect of Step Size on Accuracy")
plt.xlabel("Time t")
plt.ylabel("y(t)")
plt.legend()
plt.grid(True)
plt.show()
